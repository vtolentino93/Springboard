# %% [markdown]
# WHAT TO ASK SPLOOSH
#
# 1. how to impose .gitignore
# 2. why does the jsonfile include other dataset_codes when i try to pull only AFX_X
# 3. whats the best way to perform the calculations to figure out the questions?

# %% [markdown]
# This exercise will require you to pull some data from https://data.nasdaq.com/ (formerly Quandl API).

# %% [markdown]
# As a first step, you will need to register a free account on the https://data.nasdaq.com/ website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:
#
# *Note*: Use a `.env` file and put your key in there and `python-dotenv` to access it in this notebook.
#
# The code below uses a key that was used when generating this project but has since been deleted. Never submit your keys to source control. There is a `.env-example` file in this repository to illusrtate what you need. Copy that to a file called `.env` and use your own api key in that `.env` file. Make sure you also have a `.gitignore` file with a line for `.env` added to it.
#
# The standard Python gitignore is [here](https://github.com/github/gitignore/blob/master/Python.gitignore) you can just copy that.

# %%
# get api key from your .env file

import os
from dotenv import load_dotenv

load_dotenv(dotenv_path = 'env')
API_KEY = os.getenv('NASDAQ_API_KEY')

#print(API_KEY)

# %% [markdown]
# Nasdaq Data has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Nasdaq Data API instructions here: https://docs.data.nasdaq.com/docs/in-depth-usage

# %% [markdown]
# While there is a dedicated Python package for connecting to the Nasdaq API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules

import requests
import json

# %% [markdown]
# Note: API's can change a bit with each version, for this exercise it is reccomended to use the nasdaq api at `https://data.nasdaq.com/api/v3/`. This is the same api as what used to be quandl so `https://www.quandl.com/api/v3/` should work too.
#
# Hint: We are looking for the `AFX_X` data on the `datasets/FSE/` dataset.

# %%
# Now, call the Nasdaq API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned

url = "https://data.nasdaq.com/api/v3/datasets"

params = dict(key=API_KEY, database_code='FSE', dataset_code='AFX_X', start_date='2020-01-01', end_date='2020-01-01')
res = requests.get(url, params=params)

#res = requests.get("https://data.nasdaq.com/api/v3/datasets/WIKI/FB.json&start_date=2020-01-01&end_date=2020-01-01", key=API_KEY)

# %%
print(res.status_code)
# Out:
# 200

# %%
print(res.headers)
# Out:
# {'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': '*', 'Access-Control-Allow-Methods': 'GET, POST, OPTIONS', 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'X-RateLimit-Limit, X-RateLimit-Remaining', 'Access-Control-Max-Age': '1728000', 'Allow': 'GET, HEAD, POST, PUT, DELETE, OPTIONS, PATCH', 'Cache-Control': 'no-store', 'Content-Encoding': 'gzip', 'Content-Security-Policy': "frame-ancestors 'self';", 'Content-Type': 'application/json; charset=utf-8', 'Date': 'Sun, 13 Nov 2022 23:00:02 GMT', 'ETag': 'W/"f77196470da9501e8f3fe137d8b187b0"', 'Pragma': 'no-cache', 'Referrer-Policy': 'origin-when-cross-origin', 'Server': 'openresty', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'SAMEORIGIN', 'X-RateLimit-Limit': '50', 'X-RateLimit-Remaining': '36', 'X-Request-Id': '1bca28a4-bf27-4924-ac7d-2294fc4962b8', 'X-Runtime': '0.211586', 'X-XSS-Protection': '1; mode=block', 'Content-Length': '4895', 'Connection': 'keep-alive', 'Set-Cookie': 'visid_incap_2170999=0s7G+36rS/WKUoTYsGMabvF2cWMAAAAAQUIPAAAAAAAKnONMX2UIV11JkhHNq7Kg; expires=Mon, 13 Nov 2023 07:28:07 GMT; HttpOnly; path=/; Domain=.nasdaq.com, nlbi_2170999=4TAqWZE3RmsXjrhWKj7S7QAAAAD2XROHrvZ/bSVIAsogmL1s; path=/; Domain=.nasdaq.com, incap_ses_553_2170999=ZJR8OfwU1kDOLYI1U6esB/J2cWMAAAAAGkTGI3M7GRv/U7z224u53w==; path=/; Domain=.nasdaq.com', 'X-CDN': 'Imperva', 'X-Iinfo': '7-30948201-30948204 NNNN CT(60 127 0) RT(1668380401792 43) q(0 0 2 0) r(5 5) U2'}

# %%
print(res.text)
# Out:
# {"datasets":[{"id":45326420,"dataset_code":"VNA_X","database_code":"FSE","name":"Vonovia SE (ex Deutsche Annington) (VNA_X)","description":"Stock Prices for Vonovia SE (ex Deutsche Annington) (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE000A1ML7J1","refreshed_at":"2020-12-01T14:48:10.901Z","newest_available_date":"2020-12-01","oldest_available_date":"2013-07-11","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":45305349,"dataset_code":"1COV_X","database_code":"FSE","name":"Covestro AG (1COV_X)","description":"Stock Prices for Covestro AG (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE0006062144","refreshed_at":"2020-12-01T14:48:09.907Z","newest_available_date":"2020-12-01","oldest_available_date":"2015-10-06","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":36592406,"dataset_code":"EON_X","database_code":"FSE","name":"E.on Se (EON_X)","description":"Stock Prices for E.on Se (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE000ENAG999","refreshed_at":"2020-12-01T14:48:09.907Z","newest_available_date":"2020-12-01","oldest_available_date":"2003-01-20","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":29043743,"dataset_code":"O2D_X","database_code":"FSE","name":"Telefonica Deutschland AG (O2) (O2D_X)","description":"Stock Prices for Telefonica Deutschland AG (O2) (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE000A1J5RX9","refreshed_at":"2020-12-01T14:48:10.901Z","newest_available_date":"2020-12-01","oldest_available_date":"2012-10-30","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":10095444,"dataset_code":"ZO1_X","database_code":"FSE","name":"Zooplus (ZO1_X)","description":"Stock Prices for Zooplus (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE0005111702","refreshed_at":"2020-12-01T14:48:10.901Z","newest_available_date":"2020-12-01","oldest_available_date":"2008-05-09","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":10095443,"dataset_code":"AOX_X","database_code":"FSE","name":"alstria office REIT-AG (AOX_X)","description":"Stock Prices for alstria office REIT-AG (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE000A0LD2U1","refreshed_at":"2020-12-01T14:48:09.907Z","newest_available_date":"2020-12-01","oldest_available_date":"2014-02-26","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":10095442,"dataset_code":"WAC_X","database_code":"FSE","name":"Wacker Neuson Se (WAC_X)","description":"Stock Prices for Wacker Neuson Se (2020-11-02) from the Frankfurt  ...

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure

# %%
res.json()
# Out:
# {'datasets': [{'id': 45326420,
#    'dataset_code': 'VNA_X',
#    'database_code': 'FSE',
#    'name': 'Vonovia SE (ex Deutsche Annington) (VNA_X)',
#    'description': 'Stock Prices for Vonovia SE (ex Deutsche Annington) (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A1ML7J1',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2013-07-11',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 45305349,
#    'dataset_code': '1COV_X',
#    'database_code': 'FSE',
#    'name': 'Covestro AG (1COV_X)',
#    'description': 'Stock Prices for Covestro AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006062144',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2015-10-06',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 36592406,
#    'dataset_code': 'EON_X',
#    'database_code': 'FSE',
#    'name': 'E.on Se (EON_X)',
#    'description': 'Stock Prices for E.on Se (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000ENAG999',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2003-01-20',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 29043743,
#    'dataset_code': 'O2D_X',
#    'database_code': 'FSE',
#    'name': 'Telefonica Deutschland AG (O2) (O2D_X)',
#    'description': 'Stock Prices for Telefonica Deutschland AG (O2) (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A1J5RX9',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2012-10-30',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095444,
#    'dataset_code': 'ZO1_X',
#    'database_code': 'FSE',
#    'name': 'Zooplus (ZO1_X)',
#    'description': 'Stock Prices for Zooplus (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005111702',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2008-05-09',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095443,
#    'dataset_code': 'AOX_X',
#    'database_code': 'FSE',
#    'name': 'alstria office REIT-AG (AOX_X)',
#    'description': 'Stock Prices for alstria office REIT-AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0LD2U1',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2014-02-26',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095442,
#    'dataset_code': 'WAC_X',
#    'database_code': 'FSE',
#    'name': 'Wacker Neuson Se (WAC_X)',
#    'description': 'Stock Prices for Wacker Neuson Se (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000WACK012',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2007-05-15',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095441,
#    'dataset_code': 'VOS_X',
#    'database_code': 'FSE',
#    'name': 'Vossloh (VOS_X)',
#    'description': 'Stock Prices for Vossloh (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007667107',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-03-28',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095440,
#    'dataset_code': 'VIB3_X',
#    'database_code': 'FSE',
#    'name': 'Villeroy & Boch AG (VIB3_X)',
#    'description': 'Stock Prices for Villeroy & Boch AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007657231',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-05-19',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095437,
#    'dataset_code': 'TTK_X',
#    'database_code': 'FSE',
#    'name': 'Takkt (TTK_X)',
#    'description': 'Stock Prices for Takkt (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007446007',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095436,
#    'dataset_code': 'TTI_X',
#    'database_code': 'FSE',
#    'name': 'Tom Tailor Holding (TTI_X)',
#    'description': 'Stock Prices for Tom Tailor Holding (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0STST2',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2010-03-26',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095435,
#    'dataset_code': 'SAX_X',
#    'database_code': 'FSE',
#    'name': 'Ströer SE & Co. KGaA (SAX_X)',
#    'description': 'Stock Prices for Ströer SE & Co. KGaA (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007493991',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2010-08-06',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095434,
#    'dataset_code': 'SIX2_X',
#    'database_code': 'FSE',
#    'name': 'Sixt Se St (SIX2_X)',
#    'description': 'Stock Prices for Sixt Se St (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007231326',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095432,
#    'dataset_code': 'SW1_X',
#    'database_code': 'FSE',
#    'name': 'Shw (SW1_X)',
#    'description': 'Stock Prices for Shw (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A1JBPV9',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2011-07-07',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095430,
#    'dataset_code': 'PUM_X',
#    'database_code': 'FSE',
#    'name': 'Puma Se (PUM_X)',
#    'description': 'Stock Prices for Puma Se (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006969603',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-19',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095428,
#    'dataset_code': 'P1Z_X',
#    'database_code': 'FSE',
#    'name': 'Patrizia Immobilien (P1Z_X)',
#    'description': 'Stock Prices for Patrizia Immobilien (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000PAT1AG3',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2006-03-31',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095427,
#    'dataset_code': 'MLP_X',
#    'database_code': 'FSE',
#    'name': 'Mlp (MLP_X)',
#    'description': 'Stock Prices for Mlp (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006569908',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095426,
#    'dataset_code': 'SKB_X',
#    'database_code': 'FSE',
#    'name': 'Koenig & Bauer (SKB_X)',
#    'description': 'Stock Prices for Koenig & Bauer (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007193500',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-03',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095425,
#    'dataset_code': 'KGX_X',
#    'database_code': 'FSE',
#    'name': 'Kion Group (KGX_X)',
#    'description': 'Stock Prices for Kion Group (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000KGX8881',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2013-06-28',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095424,
#    'dataset_code': 'KWS_X',
#    'database_code': 'FSE',
#    'name': 'Kws Saat (KWS_X)',
#    'description': 'Stock Prices for Kws Saat (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007074007',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2013-12-13',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095423,
#    'dataset_code': 'JUN3_X',
#    'database_code': 'FSE',
#    'name': 'Jungheinrich (JUN3_X)',
#    'description': 'Stock Prices for Jungheinrich (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006219934',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095422,
#    'dataset_code': 'INH_X',
#    'database_code': 'FSE',
#    'name': 'Indus Holding (INH_X)',
#    'description': 'Stock Prices for Indus Holding (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006200108',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-11',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095420,
#    'dataset_code': 'HDD_X',
#    'database_code': 'FSE',
#    'name': 'Heidelberger Druckmaschinen (HDD_X)',
#    'description': 'Stock Prices for Heidelberger Druckmaschinen (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007314007',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095419,
#    'dataset_code': 'HAW_X',
#    'database_code': 'FSE',
#    'name': 'Hawesko Holding (HAW_X)',
#    'description': 'Stock Prices for Hawesko Holding (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006042708',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-03',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095418,
#    'dataset_code': 'HAB_X',
#    'database_code': 'FSE',
#    'name': 'Hamborner Reit AG (HAB_X)',
#    'description': 'Stock Prices for Hamborner Reit AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006013006',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2014-02-26',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095417,
#    'dataset_code': 'HHFA_X',
#    'database_code': 'FSE',
#    'name': 'HHLA AG (Hamburger Hafen und Logistik) (HHFA_X)',
#    'description': 'Stock Prices for HHLA AG (Hamburger Hafen und Logistik) (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0S8488',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2007-11-28',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095414,
#    'dataset_code': 'GMM_X',
#    'database_code': 'FSE',
#    'name': 'Grammer (GMM_X)',
#    'description': 'Stock Prices for Grammer (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005895403',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-06',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095413,
#    'dataset_code': 'GSC1_X',
#    'database_code': 'FSE',
#    'name': 'Gesco (GSC1_X)',
#    'description': 'Stock Prices for Gesco (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A1K0201',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-10',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095411,
#    'dataset_code': 'DEZ_X',
#    'database_code': 'FSE',
#    'name': 'Deutz (DEZ_X)',
#    'description': 'Stock Prices for Deutz (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006305006',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-03',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095410,
#    'dataset_code': 'DBAN_X',
#    'database_code': 'FSE',
#    'name': 'Deutsche Beteiligungs AG (DBAN_X)',
#    'description': 'Stock Prices for Deutsche Beteiligungs AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A1TNUT7',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-10',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095409,
#    'dataset_code': 'ANN_X',
#    'database_code': 'FSE',
#    'name': 'Deutsche Annington Immobilien Se (ANN_X)',
#    'description': 'Stock Prices for Deutsche Annington Immobilien Se (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A1ML7J1',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2013-07-11',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095408,
#    'dataset_code': 'DEX_X',
#    'database_code': 'FSE',
#    'name': 'Delticom (DEX_X)',
#    'description': 'Stock Prices for Delticom (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005146807',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2006-10-26',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095407,
#    'dataset_code': 'DIC_X',
#    'database_code': 'FSE',
#    'name': 'DIC Asset AG (DIC_X)',
#    'description': 'Stock Prices for DIC Asset AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A1X3XX4',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2005-12-26',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095405,
#    'dataset_code': 'CEV_X',
#    'database_code': 'FSE',
#    'name': 'Centrotec Sustainable (CEV_X)',
#    'description': 'Stock Prices for Centrotec Sustainable (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005407506',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-14',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095404,
#    'dataset_code': 'EVD_X',
#    'database_code': 'FSE',
#    'name': 'CTS Eventim (EVD_X)',
#    'description': 'Stock Prices for CTS Eventim (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005470306',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-02-02',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095403,
#    'dataset_code': 'CWC_X',
#    'database_code': 'FSE',
#    'name': 'Cewe Stiftung & Co. Kgaa (CWC_X)',
#    'description': 'Stock Prices for Cewe Stiftung & Co. Kgaa (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005403901',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2005-05-02',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095402,
#    'dataset_code': 'O2C_X',
#    'database_code': 'FSE',
#    'name': 'Petro Welt AG (ex cat oil) (O2C_X)',
#    'description': 'Stock Prices for Petro Welt AG (ex cat oil) (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: AT0000A00Y78',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2006-05-17',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095401,
#    'dataset_code': 'BIO3_X',
#    'database_code': 'FSE',
#    'name': 'Biotest  Vz (BIO3_X)',
#    'description': 'Stock Prices for Biotest  Vz (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005227235',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-14',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095400,
#    'dataset_code': 'BDT_X',
#    'database_code': 'FSE',
#    'name': 'Bertrandt (BDT_X)',
#    'description': 'Stock Prices for Bertrandt (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005232805',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-03',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095399,
#    'dataset_code': 'BYW6_X',
#    'database_code': 'FSE',
#    'name': 'Baywa Vna (BYW6_X)',
#    'description': 'Stock Prices for Baywa Vna (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005194062',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-11-06',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095398,
#    'dataset_code': 'B5A_X',
#    'database_code': 'FSE',
#    'name': 'Bauer Aktiengesellschaft (B5A_X)',
#    'description': 'Stock Prices for Bauer Aktiengesellschaft (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005168108',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2006-07-04',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095396,
#    'dataset_code': 'AAD_X',
#    'database_code': 'FSE',
#    'name': 'Amadeus FiRe AG (AAD_X)',
#    'description': 'Stock Prices for Amadeus FiRe AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005093108',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-02-01',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095395,
#    'dataset_code': 'AB1_X',
#    'database_code': 'FSE',
#    'name': 'Air Berlin Plc (AB1_X)',
#    'description': 'Stock Prices for Air Berlin Plc (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: GB00B128C026',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2006-05-11',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095393,
#    'dataset_code': 'WDI_X',
#    'database_code': 'FSE',
#    'name': 'Wirecard (WDI_X)',
#    'description': 'Stock Prices for Wirecard (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007472060',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2001-08-22',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095392,
#    'dataset_code': 'UTDI_X',
#    'database_code': 'FSE',
#    'name': 'United Internet (UTDI_X)',
#    'description': 'Stock Prices for United Internet (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005089031',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-08-28',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095389,
#    'dataset_code': 'SRT3_X',
#    'database_code': 'FSE',
#    'name': 'Sartorius  Vz (SRT3_X)',
#    'description': 'Stock Prices for Sartorius  Vz (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007165631',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-03-17',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095387,
#    'dataset_code': 'S92_X',
#    'database_code': 'FSE',
#    'name': 'SMA Solar AG (S92_X)',
#    'description': 'Stock Prices for SMA Solar AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0DJ6J9',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2008-06-27',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095385,
#    'dataset_code': 'QSC_X',
#    'database_code': 'FSE',
#    'name': 'Qsc (QSC_X)',
#    'description': 'Stock Prices for Qsc (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005137004',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-04-19',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095384,
#    'dataset_code': 'PFV_X',
#    'database_code': 'FSE',
#    'name': 'Pfeiffer Vacuum Technology (PFV_X)',
#    'description': 'Stock Prices for Pfeiffer Vacuum Technology (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006916604',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095383,
#    'dataset_code': 'PSAN_X',
#    'database_code': 'FSE',
#    'name': 'PSI Software AG (PSAN_X)',
#    'description': 'Stock Prices for PSI Software AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0Z1JH9',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-03-23',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095382,
#    'dataset_code': 'NDX1_X',
#    'database_code': 'FSE',
#    'name': 'Nordex Se (NDX1_X)',
#    'description': 'Stock Prices for Nordex Se (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0D6554',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2001-04-02',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095381,
#    'dataset_code': 'NEM_X',
#    'database_code': 'FSE',
#    'name': 'Nemetschek (NEM_X)',
#    'description': 'Stock Prices for Nemetschek (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006452907',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2005-05-02',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095380,
#    'dataset_code': 'MOR_X',
#    'database_code': 'FSE',
#    'name': 'Morphosys (MOR_X)',
#    'description': 'Stock Prices for Morphosys (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006632003',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095379,
#    'dataset_code': 'LPK_X',
#    'database_code': 'FSE',
#    'name': 'LPKF Laser & Electronics AG (LPK_X)',
#    'description': 'Stock Prices for LPKF Laser & Electronics AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006450000',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-03',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095376,
#    'dataset_code': 'FNTN_X',
#    'database_code': 'FSE',
#    'name': 'Freenet (FNTN_X)',
#    'description': 'Stock Prices for Freenet (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0Z2ZZ5',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095375,
#    'dataset_code': 'EVT_X',
#    'database_code': 'FSE',
#    'name': 'Evotec (EVT_X)',
#    'description': 'Stock Prices for Evotec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005664809',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-03-28',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095374,
#    'dataset_code': 'DRW3_X',
#    'database_code': 'FSE',
#    'name': 'Drägerwerk  & Co. Kgaa Vz (DRW3_X)',
#    'description': 'Stock Prices for Drägerwerk  & Co. Kgaa Vz (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005550636',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-03-20',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095373,
#    'dataset_code': 'DRI_X',
#    'database_code': 'FSE',
#    'name': 'Drillisch (DRI_X)',
#    'description': 'Stock Prices for Drillisch (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005545503',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095372,
#    'dataset_code': 'DLG_X',
#    'database_code': 'FSE',
#    'name': 'Dialog Semiconductor Plc (DLG_X)',
#    'description': 'Stock Prices for Dialog Semiconductor Plc (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: GB0059822006',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-17',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095370,
#    'dataset_code': 'AFX_X',
#    'database_code': 'FSE',
#    'name': 'Carl Zeiss Meditec (AFX_X)',
#    'description': 'Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-06-07',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095369,
#    'dataset_code': 'COK_X',
#    'database_code': 'FSE',
#    'name': 'Cancom Se (COK_X)',
#    'description': 'Stock Prices for Cancom Se (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005419105',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-03-20',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095368,
#    'dataset_code': 'BC8_X',
#    'database_code': 'FSE',
#    'name': 'Bechtle (BC8_X)',
#    'description': 'Stock Prices for Bechtle (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005158703',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-06-06',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095367,
#    'dataset_code': 'BBZA_X',
#    'database_code': 'FSE',
#    'name': 'Bb Biotech (BBZA_X)',
#    'description': 'Stock Prices for Bb Biotech (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: CH0038389992',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-20',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095366,
#    'dataset_code': 'AIXA_X',
#    'database_code': 'FSE',
#    'name': 'Aixtron Se (AIXA_X)',
#    'description': 'Stock Prices for Aixtron Se (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0WMPJ6',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095365,
#    'dataset_code': 'ADV_X',
#    'database_code': 'FSE',
#    'name': 'Adva Se (ADV_X)',
#    'description': 'Stock Prices for Adva Se (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005103006',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-03-28',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095363,
#    'dataset_code': 'WCH_X',
#    'database_code': 'FSE',
#    'name': 'Wacker Chemie (WCH_X)',
#    'description': 'Stock Prices for Wacker Chemie (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000WCH8881',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2006-04-10',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095362,
#    'dataset_code': 'TLX_X',
#    'database_code': 'FSE',
#    'name': 'Talanx Aktiengesellschaft (TLX_X)',
#    'description': 'Stock Prices for Talanx Aktiengesellschaft (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000TLX1005',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2012-10-02',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095361,
#    'dataset_code': 'TUI1_X',
#    'database_code': 'FSE',
#    'name': 'Tui (TUI1_X)',
#    'description': 'Stock Prices for Tui (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000TUAG000',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095360,
#    'dataset_code': 'TEG_X',
#    'database_code': 'FSE',
#    'name': 'Tag Immobilien (TEG_X)',
#    'description': 'Stock Prices for Tag Immobilien (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0008303504',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
# ...
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-10-13',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095348,
#    'dataset_code': 'OSR_X',
#    'database_code': 'FSE',
#    'name': 'Osram Licht (OSR_X)',
#    'description': 'Stock Prices for Osram Licht (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000LED4000',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2013-07-08',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095347,
#    'dataset_code': 'NOEJ_X',
#    'database_code': 'FSE',
#    'name': 'NORMA Group SE (NOEJ_X)',
#    'description': 'Stock Prices for NORMA Group SE (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A1H8BV3',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2011-04-08',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095346,
#    'dataset_code': 'MEO_X',
#    'database_code': 'FSE',
#    'name': 'Metro  St (MEO_X)',
#    'description': 'Stock Prices for Metro  St (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007257503',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095345,
#    'dataset_code': 'MTX_X',
#    'database_code': 'FSE',
#    'name': 'MTU Aero Engines AG (MTX_X)',
#    'description': 'Stock Prices for MTU Aero Engines AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0D9PT0',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2005-06-06',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095344,
#    'dataset_code': 'MAN_X',
#    'database_code': 'FSE',
#    'name': 'Man Se St (MAN_X)',
#    'description': 'Stock Prices for Man Se St (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005937007',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095343,
#    'dataset_code': 'LEO_X',
#    'database_code': 'FSE',
#    'name': 'Leoni (LEO_X)',
#    'description': 'Stock Prices for Leoni (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005408884',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2001-09-17',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095342,
#    'dataset_code': 'LEG_X',
#    'database_code': 'FSE',
#    'name': 'Leg Immobilien (LEG_X)',
#    'description': 'Stock Prices for Leg Immobilien (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000LEG1110',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2013-02-01',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095341,
#    'dataset_code': 'KU2_X',
#    'database_code': 'FSE',
#    'name': 'Kuka Aktiengesellschaft (KU2_X)',
#    'description': 'Stock Prices for Kuka Aktiengesellschaft (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006204407',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095340,
#    'dataset_code': 'KRN_X',
#    'database_code': 'FSE',
#    'name': 'Krones (KRN_X)',
#    'description': 'Stock Prices for Krones (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006335003',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-03',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095339,
#    'dataset_code': 'KCO_X',
#    'database_code': 'FSE',
#    'name': 'Klöckner & Co (KlöCo) (KCO_X)',
#    'description': 'Stock Prices for Klöckner & Co (KlöCo) (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000KC01000',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2006-07-26',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095337,
#    'dataset_code': 'BOSS_X',
#    'database_code': 'FSE',
#    'name': 'Hugo Boss (BOSS_X)',
#    'description': 'Stock Prices for Hugo Boss (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A1PHFF7',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-03',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095336,
#    'dataset_code': 'HOT_X',
#    'database_code': 'FSE',
#    'name': 'Hochtief (HOT_X)',
#    'description': 'Stock Prices for Hochtief (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006070006',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095335,
#    'dataset_code': 'HNR1_X',
#    'database_code': 'FSE',
#    'name': 'Hannover Rück Se (HNR1_X)',
#    'description': 'Stock Prices for Hannover Rück Se (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0008402215',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-10-25',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095333,
#    'dataset_code': 'GXI_X',
#    'database_code': 'FSE',
#    'name': 'Gerresheimer (GXI_X)',
#    'description': 'Stock Prices for Gerresheimer (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0LD6E6',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2007-06-11',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095331,
#    'dataset_code': 'G1A_X',
#    'database_code': 'FSE',
#    'name': 'GEA AG (G1A_X)',
#    'description': 'Stock Prices for GEA AG (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0006602006',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-18',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095330,
#    'dataset_code': 'FPE3_X',
#    'database_code': 'FSE',
#    'name': 'Fuchs Petrolub  Vz (FPE3_X)',
#    'description': 'Stock Prices for Fuchs Petrolub  Vz (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005790430',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-10',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095329,
#    'dataset_code': 'FRA_X',
#    'database_code': 'FSE',
#    'name': 'Fraport (FRA_X)',
#    'description': 'Stock Prices for Fraport (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005773303',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2001-06-11',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095328,
#    'dataset_code': 'FIE_X',
#    'database_code': 'FSE',
#    'name': 'Fielmann (FIE_X)',
#    'description': 'Stock Prices for Fielmann (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005772206',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-10-25',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095327,
#    'dataset_code': 'EVK_X',
#    'database_code': 'FSE',
#    'name': 'Evonik Industries (EVK_X)',
#    'description': 'Stock Prices for Evonik Industries (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000EVNK013',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2013-04-25',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095326,
#    'dataset_code': 'ZIL2_X',
#    'database_code': 'FSE',
#    'name': 'Elringklinger (ZIL2_X)',
#    'description': 'Stock Prices for Elringklinger (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0007856023',
#    'refreshed_at': '2020-12-01T14:48:10.901Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2001-09-24',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095325,
#    'dataset_code': 'DUE_X',
#    'database_code': 'FSE',
#    'name': 'Dürr (DUE_X)',
#    'description': 'Stock Prices for Dürr (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005565204',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2000-01-06',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129},
#   {'id': 10095324,
#    'dataset_code': 'DWNI_X',
#    'database_code': 'FSE',
#    'name': 'Deutsche Wohnen (DWNI_X)',
#    'description': 'Stock Prices for Deutsche Wohnen (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE000A0HN5C6',
#    'refreshed_at': '2020-12-01T14:48:09.907Z',
#    'newest_available_date': '2020-12-01',
#    'oldest_available_date': '2006-07-03',
#    'column_names': ['Date',
#     'Open',
#     'High',
#     'Low',
#     'Close',
#     'Change',
#     'Traded Volume',
#     'Turnover',
#     'Last Price of the Day',
#     'Daily Traded Units',
#     'Daily Turnover'],
#    'frequency': 'daily',
#    'type': 'Time Series',
#    'premium': False,
#    'database_id': 6129}],
#  'meta': {'query': '',
#   'per_page': 100,
#   'current_page': 1,
#   'prev_page': None,
#   'total_pages': 2,
#   'total_count': 163,
#   'next_page': 2,
#   'current_first_item': 1,
#   'current_last_item': 100}}

# %%
#id of AFX_X is '10095370'

AFX_XExtract = res['id':'10095370']
print(AFX_XExtract)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 3>()
#       1 #id of AFX_X is '10095370'
# ----> 3 AFX_XExtract = res['id':'10095370']
#       4 print(AFX_XExtract)
#
# TypeError: 'Response' object is not subscriptable

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %% [markdown]
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).

# %%
params = dict(key=API_KEY, database_code='FSE', dataset_code='AFX_X', start_date='2017-01-01', end_date='2017-12-31')
res = requests.get(url, params=params)
print(res.text)
# Out:
# {"datasets":[{"id":45326420,"dataset_code":"VNA_X","database_code":"FSE","name":"Vonovia SE (ex Deutsche Annington) (VNA_X)","description":"Stock Prices for Vonovia SE (ex Deutsche Annington) (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE000A1ML7J1","refreshed_at":"2020-12-01T14:48:10.901Z","newest_available_date":"2020-12-01","oldest_available_date":"2013-07-11","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":45305349,"dataset_code":"1COV_X","database_code":"FSE","name":"Covestro AG (1COV_X)","description":"Stock Prices for Covestro AG (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE0006062144","refreshed_at":"2020-12-01T14:48:09.907Z","newest_available_date":"2020-12-01","oldest_available_date":"2015-10-06","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":36592406,"dataset_code":"EON_X","database_code":"FSE","name":"E.on Se (EON_X)","description":"Stock Prices for E.on Se (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE000ENAG999","refreshed_at":"2020-12-01T14:48:09.907Z","newest_available_date":"2020-12-01","oldest_available_date":"2003-01-20","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":29043743,"dataset_code":"O2D_X","database_code":"FSE","name":"Telefonica Deutschland AG (O2) (O2D_X)","description":"Stock Prices for Telefonica Deutschland AG (O2) (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE000A1J5RX9","refreshed_at":"2020-12-01T14:48:10.901Z","newest_available_date":"2020-12-01","oldest_available_date":"2012-10-30","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":10095444,"dataset_code":"ZO1_X","database_code":"FSE","name":"Zooplus (ZO1_X)","description":"Stock Prices for Zooplus (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE0005111702","refreshed_at":"2020-12-01T14:48:10.901Z","newest_available_date":"2020-12-01","oldest_available_date":"2008-05-09","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":10095443,"dataset_code":"AOX_X","database_code":"FSE","name":"alstria office REIT-AG (AOX_X)","description":"Stock Prices for alstria office REIT-AG (2020-11-02) from the Frankfurt Stock Exchange.\u003cbr\u003e\u003cbr\u003eTrading System: Xetra\u003cbr\u003e\u003cbr\u003eISIN: DE000A0LD2U1","refreshed_at":"2020-12-01T14:48:09.907Z","newest_available_date":"2020-12-01","oldest_available_date":"2014-02-26","column_names":["Date","Open","High","Low","Close","Change","Traded Volume","Turnover","Last Price of the Day","Daily Traded Units","Daily Turnover"],"frequency":"daily","type":"Time Series","premium":false,"database_id":6129},{"id":10095442,"dataset_code":"WAC_X","database_code":"FSE","name":"Wacker Neuson Se (WAC_X)","description":"Stock Prices for Wacker Neuson Se (2020-11-02) from the Frankfurt  ...

# %% [markdown]
# 2. Convert the returned JSON object into a Python dictionary.

# %%
with open(res) as res:
    data = json.load(res)
    print(type(res))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 with open(res) as res:
#       2     data = json.load(res)
#       3     print(type(res))
#
# TypeError: expected str, bytes or os.PathLike object, not Response

# %% [markdown]
# 3. Calculate what the highest and lowest opening prices were for the stock in this period

# %% [markdown]
# 4. What was the largest change in any one day (based on High and Low price)?

# %% [markdown]
# 5. What was the largest change between any two days (based on Closing Price)?

# %% [markdown]
# 6. What was the average daily trading volume during this year?

# %% [markdown]
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)
